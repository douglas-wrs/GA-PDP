# %%
import auxiliary_tools
import pandas as pd
import evolution

# %%
df_rides, df_others = auxiliary_tools.load_dataset()
# Out:
# # proposals:  123402
# # requests 121427
# # rides 46616

# %%
df_reduced_points = auxiliary_tools.generalize_clients_requests(df_rides, 20)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/cluster/optics_.py:791: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = reachability_plot[:-1] / reachability_plot[1:]
# Number of clusters: 1210

# %%
evolution.plot_points(df_reduced_points, "./map.png", -49.3355, -49.2067, -16.6434, -16.7516, 'Dense Coordinate Points')
